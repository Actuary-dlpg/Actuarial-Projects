# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib as plt
import numpy as np
import pandas as pd
import datetime as dt
import re

# %%
# Data Frame para comparación de Ingresos:
AnioIng_Actual = 2024
MesIng_Actual = 12
AnioIng_Anterior = 2023
MesIng_Anterior = 12

# %% [markdown]
# ## USUARIOS POR PERIODO

# %%
Usuarios21_1 = pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_2021_1.txt', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Usuarios21_2 = pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_2021_2.txt', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Usuarios22_1 = pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_2022_1.txt', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Usuarios22_2 = pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_2022_2.txt', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Usuarios23_1 = pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_2023_1.txt', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Usuarios23_2 = pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_2023_2.txt', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Usuarios24_1 = pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_2024_1.txt', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Usuarios24_2 = pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_2024_2.txt', index_col = False, encoding='latin-1', sep = ';', low_memory = False)

# %%
a1, a2, a3, a4, a5, a6, a7, a8 = Usuarios21_1['MES'].count(), Usuarios21_2['MES'].count(), Usuarios22_1['MES'].count(), Usuarios22_2['MES'].count(), Usuarios23_1['MES'].count(),Usuarios23_2['MES'].count(), Usuarios24_1['MES'].count(), Usuarios24_2['MES'].count()
a1, a2, a3, a4, a5, a6, a7, a8
# Out:
# (np.int64(257499),
#  np.int64(261499),
#  np.int64(260367),
#  np.int64(258794),
#  np.int64(256596),
#  np.int64(250529),
#  np.int64(248627),
#  np.int64(262543))

# %%
Usuarios_Total = pd.concat([Usuarios21_1, Usuarios21_2, Usuarios22_1, Usuarios22_2, Usuarios23_1, Usuarios23_2, Usuarios24_1, Usuarios24_2], axis = 0, ignore_index = False, keys = None, sort = False, copy = True)

# %%
df_Exp = pd.DataFrame(Usuarios_Total)

# %%
df_Exp = df_Exp.rename(columns={'AÃO': 'ANO', 'Fecha afiliaciÃ³n': 'FECHA_DE_AFILIACION'})

# %%
df_Exp['Carnet'] = df_Exp['Carnet'].astype(str)
df_Exp['Carnet'] = df_Exp.apply(lambda x:x['Carnet'].replace('*', ''), axis = 1)

# %%
df_Exp['NUMERO BENEFICIA'] = df_Exp['NUMERO BENEFICIA'].fillna(1)

# %%
df_Exp['NUMERO CONTRATO'].astype(int)
df_Exp['Carnet_H'] = df_Exp['NUMERO CONTRATO'].astype(str) + df_Exp['NUMERO BENEFICIA'].apply(lambda x: f'{int(x):02}')
df_Exp
# Out:
#          ANO        MES  CIUDAD SERVICIO       Ciudad  COD CONCEPTO CONTRATO  \
# 0       2021      Enero                5  SANTA MARTA                    150
# 1       2021      Enero                5  SANTA MARTA                    150
# 2       2021      Enero                5  SANTA MARTA                    150
# 3       2021      Enero                5  SANTA MARTA                    159
# 4       2021      Enero                5  SANTA MARTA                    154
# ...      ...        ...              ...          ...                    ...
# 262538  2024  Diciembre               35        CESAR                    150
# 262539  2024  Diciembre               13      ARMENIA                    150
# 262540  2024  Diciembre               36        NEIVA                    150
# 262541  2024  Diciembre               17     MEDELLIN                    150
# 262542  2024  Diciembre               30         CALI                    154
#
#        COD ESTADO BENEFICIARIO CODPLAN Nombre Plan  NUMERO CONTRATO  \
# 0                           AC       F     Clase_B            85455
# 1                           AC      MU     Clase_G            77285
# 2                           AC      ES     Clase_J            36020
# 3                           AC      DS     Clase_T           202045
# 4                           AC       O     Clase_B           234835
# ...                        ...     ...         ...              ...
# 262538                      AC       O     Clase_B           438795
# 262539                      AC       K     Clase_G           180845
# 262540                      AC       O     Clase_B           441970
# 262541                      AC      DS     Clase_T           103515
# 262542                      AC      DS     Clase_T           211495
#
#        TIPO CONTRATO  ...  COD PARENT  FECHA NACIMIENTO  EDAD SEXO  \
# 0         Convenio_2  ...          HI         9/06/2010    10    F
# 1         Convenio_1  ...          HI         3/05/2011     9    M
# 2         Convenio_2  ...          PA        22/02/1959    61    F
# 3         Convenio_3  ...          MA        21/11/1939    81    F
# 4         Convenio_3  ...          HI        14/09/2007    13    F
# ...              ...  ...         ...               ...   ...  ...
# 262538    Convenio_2  ...          HI         8/07/2013    11    M
# 262539    Convenio_2  ...          CT         9/07/1970    54    F
# 262540    Convenio_2  ...          OT        19/08/2001    23    M
# 262541    Convenio_2  ...          CT        14/02/1988    36    F
# 262542    Convenio_3  ...          HI         8/04/1967    57    F
#
#        FECHA_DE_AFILIACION FECHA INI VIGENCIA FECHA FIN VIGENCIA  MES_NUM  \
# 0               12/07/2017         12/07/2020         11/07/2021        1
# 1               15/02/2014         15/02/2020         14/02/2021        1
# 2               30/11/2009         30/11/2020         29/11/2021        1
# 3                1/05/1992         30/06/2020         29/06/2021        1
# 4               15/08/2009         29/01/2021         28/01/2022        1
# ...                    ...                ...                ...      ...
# 262538          29/04/2024         29/04/2024         28/04/2025       12
# 262539          13/11/1992         31/10/2024         30/10/2025       12
# 262540          15/09/2003         12/04/2024         11/04/2025       12
# 262541          31/10/2016         31/10/2024         30/10/2025       12
# 262542          17/11/1995         17/12/2024         16/12/2025       12
#
#        MES_FORMATO  Carnet_H
# 0          2021-01   8545505
# 1          2021-01   7728501
# 2          2021-01   3602002
# 3          2021-01  20204503
# 4          2021-01  23483504
# ...            ...       ...
# 262538     2024-12  43879502
# 262539     2024-12  18084501
# 262540     2024-12  44197001
# 262541     2024-12  10351501
# 262542     2024-12  21149501
#
# [2056454 rows x 25 columns]

# %%
df_Exp['FECHA INI VIGENCIA'] = pd.to_datetime(df_Exp['FECHA INI VIGENCIA'], errors='coerce', format = ('%d/%m/%Y'))
df_Exp['FECHA FIN VIGENCIA'] = pd.to_datetime(df_Exp['FECHA FIN VIGENCIA'], errors='coerce', format = ('%d/%m/%Y'))
df_Exp['FECHA NACIMIENTO'] = pd.to_datetime(df_Exp['FECHA NACIMIENTO'], errors='coerce', format = ('%d/%m/%Y'))
df_Exp['FECHA_DE_AFILIACION'] = pd.to_datetime(df_Exp['FECHA_DE_AFILIACION'], errors='coerce', format = ('%d/%m/%Y'))

# %%
df_Exp['COD PARENT'] = df_Exp['COD PARENT'].str.strip()
df_Exp['SEXO'] = df_Exp['SEXO'].str.strip()
df_Exp['Nombre Plan'] = df_Exp['Nombre Plan'].str.strip()
df_Exp['TIPO CONTRATO'] = df_Exp['TIPO CONTRATO'].str.strip()
df_Exp['Ciudad'] = df_Exp['Ciudad'].str.strip()

# %%
df_Exp['Nombre Plan'] = df_Exp.apply(lambda x:x['Nombre Plan'].replace('  ', ' '), axis = 1)

# %%
df_Exp['Nombre Plan'] = (df_Exp['Nombre Plan']
                        .str.replace('Á','A')
                        .str.replace('É','E')
                        .str.replace('Í','I')
                        .str.replace('Ó','O')
                        .str.replace('Ú','U')
                        .str.replace('á','a')
                        .str.replace('é','e')
                        .str.replace('í','i')
                        .str.replace('ó','o')
                        .str.replace('ú','u')
                        .str.replace('ñ','n'))

# %%
df_Exp['NUMERO CONTRATO'] = df_Exp['NUMERO CONTRATO'].fillna(98989898)
df_Exp['Carnet'] = df_Exp['Carnet'].fillna(98989898)
df_Exp['Carnet_H'] = df_Exp['Carnet_H'].fillna(98989898)
df_Exp['COD PARENT'] = df_Exp['COD PARENT'].fillna('0')
df_Exp['EDAD'] = df_Exp['EDAD'].fillna(9999)
df_Exp['SEXO'] = df_Exp['SEXO'].fillna('0')
df_Exp['TIPO CONTRATO'] = df_Exp['TIPO CONTRATO'].fillna('0')
df_Exp['Nombre Plan'] = df_Exp['Nombre Plan'].fillna('0')
df_Exp['CODMATRIZ'] = df_Exp['CODMATRIZ'].fillna(9999)
df_Exp['Ciudad'] = df_Exp['Ciudad'].fillna('0')
df_Exp['FECHA INI VIGENCIA'] = df_Exp['FECHA INI VIGENCIA'].fillna(value=pd.to_datetime('1/1/1900'))
df_Exp['FECHA FIN VIGENCIA'] = df_Exp['FECHA FIN VIGENCIA'].fillna(value=pd.to_datetime('1/1/1900'))
df_Exp['FECHA NACIMIENTO'] = df_Exp['FECHA NACIMIENTO'].fillna(value=pd.to_datetime('1/1/1900'))
df_Exp['FECHA_DE_AFILIACION'] = df_Exp['FECHA_DE_AFILIACION'].fillna(value=pd.to_datetime('1/1/1900'))
df_Exp['CODPLAN'] = df_Exp['CODPLAN'].fillna('999999')
df_Exp['NUM ALIANZA'] = df_Exp['NUM ALIANZA'].fillna(999999)

# %%
df_Exp['EDAD'] = df_Exp['EDAD'].clip(lower=0)

# %%
df_Exp['NUMERO CONTRATO'].isna().sum()
# Out:
# np.int64(0)

# %%
df_Exp['MES'] = df_Exp['MES'].str.capitalize()

# %%
Meses = pd.read_csv('/content/drive/MyDrive/Tablas_Homologadoras/Meses.csv', index_col = False, encoding='latin-1', sep = ';')

# %%
df_Meses = pd.DataFrame(Meses)

# %%
df_Exp = pd.merge(left = df_Exp, right = df_Meses, how = 'left', left_on = (['MES']), right_on = (['Mes_L']))
df_Exp
# Out:
#           ANO        MES  CIUDAD SERVICIO       Ciudad  COD CONCEPTO CONTRATO  \
# 0        2021      Enero                5  SANTA MARTA                    150
# 1        2021      Enero                5  SANTA MARTA                    150
# 2        2021      Enero                5  SANTA MARTA                    150
# 3        2021      Enero                5  SANTA MARTA                    159
# 4        2021      Enero                5  SANTA MARTA                    154
# ...       ...        ...              ...          ...                    ...
# 2056449  2024  Diciembre               35        CESAR                    150
# 2056450  2024  Diciembre               13      ARMENIA                    150
# 2056451  2024  Diciembre               36        NEIVA                    150
# 2056452  2024  Diciembre               17     MEDELLIN                    150
# 2056453  2024  Diciembre               30         CALI                    154
#
#         COD ESTADO BENEFICIARIO CODPLAN Nombre Plan  NUMERO CONTRATO  \
# 0                            AC       F     Clase_B            85455
# 1                            AC      MU     Clase_G            77285
# 2                            AC      ES     Clase_J            36020
# 3                            AC      DS     Clase_T           202045
# 4                            AC       O     Clase_B           234835
# ...                         ...     ...         ...              ...
# 2056449                      AC       O     Clase_B           438795
# 2056450                      AC       K     Clase_G           180845
# 2056451                      AC       O     Clase_B           441970
# 2056452                      AC      DS     Clase_T           103515
# 2056453                      AC      DS     Clase_T           211495
#
#         TIPO CONTRATO  ...  EDAD  SEXO  FECHA_DE_AFILIACION  \
# 0          Convenio_2  ...    10     F           2017-07-12
# 1          Convenio_1  ...     9     M           2014-02-15
# 2          Convenio_2  ...    61     F           2009-11-30
# 3          Convenio_3  ...    81     F           1992-05-01
# 4          Convenio_3  ...    13     F           2009-08-15
# ...               ...  ...   ...   ...                  ...
# 2056449    Convenio_2  ...    11     M           2024-04-29
# 2056450    Convenio_2  ...    54     F           1992-11-13
# 2056451    Convenio_2  ...    23     M           2003-09-15
# 2056452    Convenio_2  ...    36     F           2016-10-31
# 2056453    Convenio_3  ...    57     F           1995-11-17
#
#         FECHA INI VIGENCIA FECHA FIN VIGENCIA MES_NUM MES_FORMATO  Carnet_H  \
# 0               2020-07-12         2021-07-11       1     2021-01   8545505
# 1               2020-02-15         2021-02-14       1     2021-01   7728501
# 2               2020-11-30         2021-11-29       1     2021-01   3602002
# 3               2020-06-30         2021-06-29       1     2021-01  20204503
# 4               2021-01-29         2022-01-28       1     2021-01  23483504
# ...                    ...                ...     ...         ...       ...
# 2056449         2024-04-29         2025-04-28      12     2024-12  43879502
# 2056450         2024-10-31         2025-10-30      12     2024-12  18084501
# 2056451         2024-04-12         2025-04-11      12     2024-12  44197001
# 2056452         2024-10-31         2025-10-30      12     2024-12  10351501
# 2056453         2024-12-17         2025-12-16      12     2024-12  21149501
#
#              Mes_L Mes_N
# 0            Enero     1
# 1            Enero     1
# 2            Enero     1
# 3            Enero     1
# 4            Enero     1
# ...            ...   ...
# 2056449  Diciembre    12
# 2056450  Diciembre    12
# 2056451  Diciembre    12
# 2056452  Diciembre    12
# 2056453  Diciembre    12
#
# [2056454 rows x 27 columns]

# %%
error = df_Exp[df_Exp['Mes_N'].isna()]
error
# Out:
# Empty DataFrame
# Columns: [ANO, MES, CIUDAD SERVICIO, Ciudad, COD CONCEPTO CONTRATO, COD ESTADO BENEFICIARIO, CODPLAN, Nombre Plan, NUMERO CONTRATO, TIPO CONTRATO, CODMATRIZ, NUM ALIANZA, NUMERO BENEFICIA, Carnet, TIPO ID, COD PARENT, FECHA NACIMIENTO, EDAD, SEXO, FECHA_DE_AFILIACION, FECHA INI VIGENCIA, FECHA FIN VIGENCIA, MES_NUM, MES_FORMATO, Carnet_H, Mes_L, Mes_N]
# Index: []
#
# [0 rows x 27 columns]

# %%
error['MES'].unique()
# Out:
# array([], dtype=object)

# %%
df_Exp['Fecha'] = pd.to_datetime(df_Exp['ANO'].astype(str) + '/' + df_Exp['Mes_N'].astype(str).str.zfill(2), format="%Y/%m")

# %%
# La variable conteo me sirve para contar cada persona por meses (Usuarios)
df_Exp['Usuarios'] = 1
df_Exp['Usuarios'].sum()
# Out:
# np.int64(2056454)

# %%
Usuarios = df_Exp[['Fecha','ANO', 'MES', 'Mes_N', 'Ciudad','CODPLAN', 'Nombre Plan', 'NUMERO CONTRATO', 'TIPO CONTRATO',
                   'CODMATRIZ', 'NUM ALIANZA', 'Carnet', 'COD PARENT', 'FECHA NACIMIENTO',
                   'EDAD', 'SEXO', 'FECHA_DE_AFILIACION', 'Usuarios']]
Usuarios
# Out:
#              Fecha   ANO        MES  Mes_N       Ciudad CODPLAN Nombre Plan  \
# 0       2021-01-01  2021      Enero      1  SANTA MARTA       F     Clase_B
# 1       2021-01-01  2021      Enero      1  SANTA MARTA      MU     Clase_G
# 2       2021-01-01  2021      Enero      1  SANTA MARTA      ES     Clase_J
# 3       2021-01-01  2021      Enero      1  SANTA MARTA      DS     Clase_T
# 4       2021-01-01  2021      Enero      1  SANTA MARTA       O     Clase_B
# ...            ...   ...        ...    ...          ...     ...         ...
# 2056449 2024-12-01  2024  Diciembre     12        CESAR       O     Clase_B
# 2056450 2024-12-01  2024  Diciembre     12      ARMENIA       K     Clase_G
# 2056451 2024-12-01  2024  Diciembre     12        NEIVA       O     Clase_B
# 2056452 2024-12-01  2024  Diciembre     12     MEDELLIN      DS     Clase_T
# 2056453 2024-12-01  2024  Diciembre     12         CALI      DS     Clase_T
#
#          NUMERO CONTRATO TIPO CONTRATO  CODMATRIZ  NUM ALIANZA    Carnet  \
# 0                  85455    Convenio_2          0         7011   8545505
# 1                  77285    Convenio_1      11097            0   7728501
# 2                  36020    Convenio_2          0         7200   3602002
# 3                 202045    Convenio_3          0            0  20204503
# 4                 234835    Convenio_3          0            0  23483504
# ...                  ...           ...        ...          ...       ...
# 2056449           438795    Convenio_2      18611        16627      #N/D
# 2056450           180845    Convenio_2      18611          648  18084501
# 2056451           441970    Convenio_2      18611        10098      #N/D
# 2056452           103515    Convenio_2      18611         9846  10351501
# 2056453           211495    Convenio_3      18611            0  21149501
#
#         COD PARENT FECHA NACIMIENTO  EDAD SEXO FECHA_DE_AFILIACION  Usuarios
# 0               HI       2010-06-09    10    F          2017-07-12         1
# 1               HI       2011-05-03     9    M          2014-02-15         1
# 2               PA       1959-02-22    61    F          2009-11-30         1
# 3               MA       1939-11-21    81    F          1992-05-01         1
# 4               HI       2007-09-14    13    F          2009-08-15         1
# ...            ...              ...   ...  ...                 ...       ...
# 2056449         HI       2013-07-08    11    M          2024-04-29         1
# 2056450         CT       1970-07-09    54    F          1992-11-13         1
# 2056451         OT       2001-08-19    23    M          2003-09-15         1
# 2056452         CT       1988-02-14    36    F          2016-10-31         1
# 2056453         HI       1967-04-08    57    F          1995-11-17         1
#
# [2056454 rows x 18 columns]

# %%
Usuarios = pd.DataFrame(Usuarios)

# %%
Usuarios.to_csv('/content/drive/MyDrive/Usuarios/Resultados/Usuarios_PBI.txt', sep = ';', encoding = 'utf-8', index = False)

# %%
Usuarios_Finales = pd.DataFrame(Usuarios.groupby(['Fecha', 'Nombre Plan']).agg({'Usuarios':'sum'}).astype(int).reset_index())
Usuarios_Finales
# Out:
#          Fecha Nombre Plan  Usuarios
# 0   2021-01-01     Clase_B      8635
# 1   2021-01-01     Clase_C      1127
# 2   2021-01-01     Clase_E      1934
# 3   2021-01-01     Clase_G      5676
# 4   2021-01-01     Clase_J      9748
# ..         ...         ...       ...
# 640 2024-12-01     Clase_S       624
# 641 2024-12-01     Clase_T     11413
# 642 2024-12-01     Clase_V        14
# 643 2024-12-01     Clase_X       480
# 644 2024-12-01     Clase_Z       152
#
# [645 rows x 3 columns]

# %% [markdown]
# ## USUARIOS NETOS

# %%
Usuarios_Netos_21= pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_Netos_2021.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Usuarios_Netos_22= pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_Netos_2022.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Usuarios_Netos_23= pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_Netos_2023.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Usuarios_Netos_24= pd.read_csv('/content/drive/MyDrive/Usuarios/Usuarios_Netos_2024.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)

# %%
b1, b2, b3, b4 = Usuarios_Netos_21['PERIODO CIERRE'].count(), Usuarios_Netos_22['PERIODO CIERRE'].count(), Usuarios_Netos_23['PERIODO CIERRE'].count(), Usuarios_Netos_24['PERIODO CIERRE'].count()

b1, b2, b3, b4
# Out:
# (np.int64(23661), np.int64(25170), np.int64(23370), np.int64(25908))

# %%
Netos_Total = pd.concat([Usuarios_Netos_21, Usuarios_Netos_22, Usuarios_Netos_23, Usuarios_Netos_24], axis = 0, ignore_index = False, keys = None, sort = False, copy = True)

# %%
Netos_Total['PERIODO CIERRE'] = pd.to_datetime(Netos_Total['PERIODO CIERRE']).dt.to_period('M').astype(str).str.replace('-', '/')
# Out:
# <ipython-input-34-34ddca110e74>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   Netos_Total['PERIODO CIERRE'] = pd.to_datetime(Netos_Total['PERIODO CIERRE']).dt.to_period('M').astype(str).str.replace('-', '/')

# %%
Netos_Total['PERIODO CIERRE'] = pd.to_datetime(Netos_Total['PERIODO CIERRE'])
# Out:
# <ipython-input-35-63f0315c366a>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Netos_Total['PERIODO CIERRE'] = pd.to_datetime(Netos_Total['PERIODO CIERRE'])

# %%
df_Netos = pd.DataFrame(Netos_Total)
df_Netos
# Out:
#       FECHA REALIZA NOVEDAD PERIODO CIERRE  CODIGO SUCURSAL   REGIONAL  \
# 0                22/12/2020     2021-01-01               36      NEIVA
# 1                29/12/2020     2021-01-01                7     ARAUCA
# 2                12/01/2021     2021-01-01               55     BOYACA
# 3                12/01/2021     2021-01-01               47  CARTAGENA
# 4                12/01/2021     2021-01-01               30       CALI
# ...                     ...            ...              ...        ...
# 25903            24/12/2024     2024-12-01               15   CASANARE
# 25904            27/12/2024     2024-12-01               15   CASANARE
# 25905            30/12/2024     2024-12-01               15   CASANARE
# 25906            26/12/2024     2024-12-01               15   CASANARE
# 25907            23/12/2024     2024-12-01               15   CASANARE
#
#        NUMERO CONTRATO TIPO CONTRATO  TIPO MOVIMIENTO   MOVIMIENTO  \
# 0                 6534    Convenio_2               30  Cancelación
# 1                 6535    Convenio_1               30  Cancelación
# 2                 6536    Convenio_1               30  Cancelación
# 3                 6537    Convenio_1               30  Cancelación
# 4                 6538    Convenio_1               30  Cancelación
# ...                ...           ...              ...          ...
# 25903           484090    Convenio_2               50       Nuevos
# 25904           487940    Convenio_2               50       Nuevos
# 25905           488140    Convenio_2               50       Nuevos
# 25906           434835    Convenio_2               52       Nuevos
# 25907           488815    Convenio_2               82    Traslados
#
#       FECHA INICIAL VIGENCIA FECHA FINAL VIGENCIA  ...  \
# 0                  1/01/2020           31/12/2020  ...
# 1                  1/01/2020           31/12/2020  ...
# 2                  1/01/2021           31/12/2021  ...
# 3                  1/01/2021           31/12/2021  ...
# 4                  1/01/2021           31/12/2021  ...
# ...                      ...                  ...  ...
# 25903             24/12/2024           23/12/2025  ...
# 25904             27/12/2024           26/12/2025  ...
# 25905             30/12/2024           29/12/2025  ...
# 25906             11/03/2024           10/03/2025  ...
# 25907             23/12/2024           22/12/2025  ...
#
#                                        DEFINICION CAUSAL CODPLAN  NOMBRE PLAN  \
# 0                             POR CONDICION DEL CONTRATO      DS      Clase_T
# 1                            TRASLADO CONTRATO CONVENIOS       M      Clase_S
# 2      NEGACION SERVICIOS POR CONCEPTO MEDICO ASISTEN...       M      Clase_S
# 3                                  SEPARACION - DIVORCIO       M      Clase_S
# 4           MORA DEL CONTRATO-PERMANENCIA MAYOR A UN AÑO       M      Clase_S
# ...                                                  ...     ...          ...
# 25903                        MAL SERVICIO ADMINISTRATIVO       O      Clase_B
# 25904                        TRASLADO CONTRATO CONVENIOS       C      Clase_E
# 25905                RETIRO DE LA COMPAÑÍA GRUPO MEDPLUS       O      Clase_B
# 25906                    SIN USO- POR PLAN DE BENEFICIOS       O      Clase_B
# 25907                         POR CONDICION DEL CONTRATO       F      Clase_B
#
#        COD FORMA PAGO TIPO IDENTIFICACION ASESOR FECHA RADICACION  \
# 0                   S                          C        7/01/2014
# 1                   S                          C        0/01/1900
# 2                   S                          C       27/05/2011
# 3                   S                          C        0/01/1900
# 4                   S                          C        0/01/1900
# ...               ...                        ...              ...
# 25903               M                          C       21/12/2024
# 25904               M                          C       27/12/2024
# 25905               M                          C       24/12/2024
# 25906               M                          C       24/12/2024
# 25907               M                          C       20/12/2024
#
#        VALOR NOVEDAD   VLRNOVEDAD DCTO POS    VALOR IVA   Vr.Mensualizado
# 0                 NaN                   NaN          NaN               NaN
# 1                 NaN                   NaN          NaN               NaN
# 2                 NaN                   NaN          NaN               NaN
# 3                 NaN                   NaN          NaN               NaN
# 4                 NaN                   NaN          NaN               NaN
# ...               ...                   ...          ...               ...
# 25903    2.302.888,00                  -      115.144,00        191.907,00
# 25904    1.152.017,00                  -       57.601,00         96.001,00
# 25905      667.985,00                  -       33.399,00         55.665,00
# 25906      244.626,00                  -       12.231,00         97.850,00
# 25907    1.072.398,00                  -       53.619,00         89.366,00
#
# [98109 rows x 29 columns]

# %%
df_Netos['MOVIMIENTO'] = (df_Netos['MOVIMIENTO']
                        .str.replace('Á','A')
                        .str.replace('É','E')
                        .str.replace('Í','I')
                        .str.replace('Ó','O')
                        .str.replace('Ú','U')
                        .str.replace('á','a')
                        .str.replace('é','e')
                        .str.replace('í','i')
                        .str.replace('ó','o')
                        .str.replace('ú','u')
                        .str.replace('ñ','n'))

df_Netos['MOVIMIENTO'] = df_Netos['MOVIMIENTO'].str.upper()

# %%
df_Netos['REGIONAL'] = df_Netos['REGIONAL'].fillna('0')
df_Netos['TIPO CONTRATO'] = df_Netos['TIPO CONTRATO'].fillna('0')
df_Netos['COD HOM'] = df_Netos['COD HOM'].fillna(9999)
df_Netos['DEFINICION CAUSAL'] = df_Netos['DEFINICION CAUSAL'].fillna('0')
df_Netos['CODPLAN'] = df_Netos['CODPLAN'].fillna('0')

# %%
df_Netos['NOMBRE PLAN'] = df_Netos.apply(lambda x: str(x['NOMBRE PLAN']).replace(',', '').replace('"', '').replace('  ', ' '), axis=1)

# %%
df_Netos['NOMBRE PLAN'] = (df_Netos['NOMBRE PLAN']
                .str.replace('Á', 'A', regex=False)
                .str.replace('É', 'E', regex=False)
                .str.replace('Í', 'I', regex=False)
                .str.replace('Ó', 'O', regex=False)
                .str.replace('Ú', 'U', regex=False)
                .str.replace('Ñ', 'N', regex=False)
                .str.replace('á', 'a', regex=False)
                .str.replace('é', 'e', regex=False)
                .str.replace('í', 'i', regex=False)
                .str.replace('ó', 'o', regex=False)
                .str.replace('ú', 'u', regex=False)
                .str.replace('ñ', 'n', regex=False)
                .str.replace('?', 'e', regex=False)
                .str.replace(',', '', regex=False)
                .str.replace('"', '', regex=False)
                .str.replace('  ', ' ', regex=False))

# %%
df_Netos.loc[df_Netos['MOVIMIENTO'].isin(['CANCELACION', 'TRASLADOS', 'REACTIVACION']), 'Usuario_Final'] = 'CANCELACION'
df_Netos.loc[df_Netos['MOVIMIENTO'] == 'NUEVOS', 'Usuario_Final'] = 'NUEVOS'

# %%
Usuarios_Netos_0 = pd.DataFrame(df_Netos.groupby(['PERIODO CIERRE', 'REGIONAL', 'NUMERO CONTRATO','TIPO CONTRATO', 'COD HOM', 'DEFINICION CAUSAL', 'CODPLAN', 'NOMBRE PLAN', 'Usuario_Final'])['NUMERO USUARIOS'].sum().unstack(fill_value=0).reset_index())

Usuarios_Netos = Usuarios_Netos_0.rename(columns={'CANCELACION': "Usuarios_Cancelados", "NUEVOS": "Usuarios_Nuevos"})
Usuarios_Netos['Usuarios_Cancelados'] = Usuarios_Netos['Usuarios_Cancelados'] * -1

Usuarios_Netos = pd.DataFrame(Usuarios_Netos)
Usuarios_Netos
# Out:
# Usuario_Final PERIODO CIERRE       REGIONAL  NUMERO CONTRATO TIPO CONTRATO  \
# 0                 2021-01-01         ARAUCA             6535    Convenio_1
# 1                 2021-01-01         ARAUCA             6551    Convenio_3
# 2                 2021-01-01         ARAUCA             6552    Convenio_3
# 3                 2021-01-01         ARAUCA             6553    Convenio_3
# 4                 2021-01-01         ARAUCA             6554    Convenio_2
# ...                      ...            ...              ...           ...
# 98086             2024-12-01  VILLAVICENCIO           488490    Convenio_1
# 98087             2024-12-01  VILLAVICENCIO           488495    Convenio_1
# 98088             2024-12-01  VILLAVICENCIO           488500    Convenio_1
# 98089             2024-12-01  VILLAVICENCIO           488505    Convenio_1
# 98090             2024-12-01  VILLAVICENCIO           488510    Convenio_1
#
# Usuario_Final  COD HOM                            DEFINICION CAUSAL CODPLAN  \
# 0                   45                  TRASLADO CONTRATO CONVENIOS       M
# 1                  420  TRASLADO A OTRA CIUDAD SIN RED DE SERVICIOS      FO
# 2                  615                               POR RETICENCIA      SY
# 3                  720          RETIRO ANTES DE 30 DIAS DE VIGENCIA      ES
# 4                  630   EN DESACUERDO POR NO ACEPTACION DE USUARIO      DS
# ...                ...                                          ...     ...
# 98086               60                  TRASLADO CONTRATO CONVENIOS       F
# 98087              240                                FALLECIMIENTO       F
# 98088              615                               POR RETICENCIA       F
# 98089              675           POR DECISION UNILATERAL DE MEDPLUS       F
# 98090              360                   NO TIENE VINCULACION A EPS       F
#
# Usuario_Final NOMBRE PLAN  Usuarios_Cancelados  Usuarios_Nuevos
# 0                 Clase_S                    3                0
# 1                 Clase_G                    2                0
# 2                 Clase_E                    1                0
# 3                 Clase_J                    1                0
# 4                 Clase_T                    1                0
# ...                   ...                  ...              ...
# 98086             Clase_B                   -4                0
# 98087             Clase_B                   -3                0
# 98088             Clase_B                   -7                0
# 98089             Clase_B                   -2                0
# 98090             Clase_B                   -4                0
#
# [98091 rows x 10 columns]

# %%
Usuarios_Netos_1 = pd.DataFrame(Usuarios_Netos.groupby(['PERIODO CIERRE', 'NOMBRE PLAN']).agg({'Usuarios_Nuevos':'sum', 'Usuarios_Cancelados': 'sum'}).astype(int).reset_index())
Usuarios_Netos_1
# Out:
# Usuario_Final PERIODO CIERRE NOMBRE PLAN  Usuarios_Nuevos  Usuarios_Cancelados
# 0                 2021-01-01     Clase_B              393                  347
# 1                 2021-01-01     Clase_C               55                   88
# 2                 2021-01-01     Clase_E              196                   68
# 3                 2021-01-01     Clase_G              156                  203
# 4                 2021-01-01     Clase_J               76                  147
# ..                       ...         ...              ...                  ...
# 500               2024-12-01     Clase_M                1                   -1
# 501               2024-12-01     Clase_S               17                   24
# 502               2024-12-01     Clase_T              108                  195
# 503               2024-12-01     Clase_X                4                    2
# 504               2024-12-01     Clase_Z                4                    2
#
# [505 rows x 4 columns]

# %%
Netos_Finales = pd.DataFrame(Usuarios_Netos.groupby(['PERIODO CIERRE', 'REGIONAL', 'NUMERO CONTRATO', 'TIPO CONTRATO', 'COD HOM', 'DEFINICION CAUSAL', 'CODPLAN', 'NOMBRE PLAN']).agg({'Usuarios_Cancelados':'sum', 'Usuarios_Nuevos': 'sum'}).astype(int).reset_index())
Netos_Finales
# Out:
# Usuario_Final PERIODO CIERRE       REGIONAL  NUMERO CONTRATO TIPO CONTRATO  \
# 0                 2021-01-01         ARAUCA             6535    Convenio_1
# 1                 2021-01-01         ARAUCA             6551    Convenio_3
# 2                 2021-01-01         ARAUCA             6552    Convenio_3
# 3                 2021-01-01         ARAUCA             6553    Convenio_3
# 4                 2021-01-01         ARAUCA             6554    Convenio_2
# ...                      ...            ...              ...           ...
# 98086             2024-12-01  VILLAVICENCIO           488490    Convenio_1
# 98087             2024-12-01  VILLAVICENCIO           488495    Convenio_1
# 98088             2024-12-01  VILLAVICENCIO           488500    Convenio_1
# 98089             2024-12-01  VILLAVICENCIO           488505    Convenio_1
# 98090             2024-12-01  VILLAVICENCIO           488510    Convenio_1
#
# Usuario_Final  COD HOM                            DEFINICION CAUSAL CODPLAN  \
# 0                   45                  TRASLADO CONTRATO CONVENIOS       M
# 1                  420  TRASLADO A OTRA CIUDAD SIN RED DE SERVICIOS      FO
# 2                  615                               POR RETICENCIA      SY
# 3                  720          RETIRO ANTES DE 30 DIAS DE VIGENCIA      ES
# 4                  630   EN DESACUERDO POR NO ACEPTACION DE USUARIO      DS
# ...                ...                                          ...     ...
# 98086               60                  TRASLADO CONTRATO CONVENIOS       F
# 98087              240                                FALLECIMIENTO       F
# 98088              615                               POR RETICENCIA       F
# 98089              675           POR DECISION UNILATERAL DE MEDPLUS       F
# 98090              360                   NO TIENE VINCULACION A EPS       F
#
# Usuario_Final NOMBRE PLAN  Usuarios_Cancelados  Usuarios_Nuevos
# 0                 Clase_S                    3                0
# 1                 Clase_G                    2                0
# 2                 Clase_E                    1                0
# 3                 Clase_J                    1                0
# 4                 Clase_T                    1                0
# ...                   ...                  ...              ...
# 98086             Clase_B                   -4                0
# 98087             Clase_B                   -3                0
# 98088             Clase_B                   -7                0
# 98089             Clase_B                   -2                0
# 98090             Clase_B                   -4                0
#
# [98091 rows x 10 columns]

# %%
Netos_Finales.to_csv('/content/drive/MyDrive/Usuarios/Resultados/Usuarios_Netos_V_V.txt', sep = ';', encoding = 'utf-8', index = False)

# %%
Netos_Total = pd.merge(left = Usuarios_Finales, right = Usuarios_Netos_1, how = 'left', left_on = (['Fecha','Nombre Plan']), right_on = (['PERIODO CIERRE','NOMBRE PLAN']))

Netos_Total.drop(columns=['PERIODO CIERRE','NOMBRE PLAN'], inplace=True)
Netos_Total['Usuarios_Cancelados'] = Netos_Total['Usuarios_Cancelados'].fillna(0).astype(int)
Netos_Total['Usuarios_Nuevos'] = Netos_Total['Usuarios_Nuevos'].fillna(0).astype(int)
Netos_Total['Nombre Plan'] = Netos_Total['Nombre Plan'].fillna('-')
Netos_Total['Usuario_Anterior'] = Netos_Total.groupby('Nombre Plan')['Usuarios'].shift(1)
Netos_Total['Usuario_Anterior'] = Netos_Total['Usuario_Anterior'].fillna(0).astype(int)
Netos_Total
# Out:
#          Fecha Nombre Plan  Usuarios  Usuarios_Nuevos  Usuarios_Cancelados  \
# 0   2021-01-01     Clase_B      8635              393                  347
# 1   2021-01-01     Clase_C      1127               55                   88
# 2   2021-01-01     Clase_E      1934              196                   68
# 3   2021-01-01     Clase_G      5676              156                  203
# 4   2021-01-01     Clase_J      9748               76                  147
# ..         ...         ...       ...              ...                  ...
# 640 2024-12-01     Clase_S       624               17                   24
# 641 2024-12-01     Clase_T     11413              108                  195
# 642 2024-12-01     Clase_V        14                0                    0
# 643 2024-12-01     Clase_X       480                4                    2
# 644 2024-12-01     Clase_Z       152                4                    2
#
#      Usuario_Anterior
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 640               621
# 641             11421
# 642                12
# 643               516
# 644               141
#
# [645 rows x 6 columns]

# %%
Netos_Total.to_csv('/content/drive/MyDrive/Usuarios/Resultados/Usuarios_Netos_1_V.txt', sep = ';', encoding = 'utf-8', index = False)

# %% [markdown]
# ## INGRESOS POR USUARIO.

# %%
Ing_21_1= pd.read_csv('/content/drive/MyDrive/Usuarios/IngUsuExp_2021_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Ing_21_2= pd.read_csv('/content/drive/MyDrive/Usuarios/IngUsuExp_2021_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Ing_22_1= pd.read_csv('/content/drive/MyDrive/Usuarios/IngUsuExp_2022_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Ing_22_2= pd.read_csv('/content/drive/MyDrive/Usuarios/IngUsuExp_2022_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Ing_23_1= pd.read_csv('/content/drive/MyDrive/Usuarios/IngUsuExp_2023_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Ing_23_2= pd.read_csv('/content/drive/MyDrive/Usuarios/IngUsuExp_2023_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Ing_24_1= pd.read_csv('/content/drive/MyDrive/Usuarios/IngUsuExp_2024_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Ing_24_2= pd.read_csv('/content/drive/MyDrive/Usuarios/IngUsuExp_2024_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)

# %%
b1, b2, b3, b4, b5, b6, b7, b8 = Ing_21_1['AnioIng'].count(), Ing_21_2['AnioIng'].count(), Ing_22_1['AnioIng'].count(), Ing_22_2['AnioIng'].count(), Ing_23_1['AnioIng'].count(), Ing_23_2['AnioIng'].count(), Ing_24_1['AnioIng'].count(), Ing_24_2['AnioIng'].count()
b1, b2, b3, b4, b5, b6, b7, b8
# Out:
# (np.int64(1001101),
#  np.int64(85249),
#  np.int64(717543),
#  np.int64(222426),
#  np.int64(692161),
#  np.int64(130621),
#  np.int64(677975),
#  np.int64(58868))

# %%
Ing_Total = pd.concat([Ing_21_1, Ing_21_2, Ing_22_1, Ing_22_2, Ing_23_1, Ing_23_2, Ing_24_1, Ing_24_2], axis = 0, ignore_index = False, keys = None, sort = False, copy = True)
Ing_Total
# Out:
#        AnioIng  MesIng  numerocontrato  CarnetUsuario Parentesco  Edad Sexo  \
# 0         2021       1          205505       20550502         HI    25    M
# 1         2021       1          205505       20550505         CT    51    F
# 2         2021       1          205505       20550506         HI    20    F
# 3         2021       1          205505       20550507         PA    64    F
# 4         2021       1          218120       21812003         CT    58    M
# ...        ...     ...             ...            ...        ...   ...  ...
# 58863     2024      12          263540       26354001         CT    50    M
# 58864     2024      12          263595       26359501         CT    57    F
# 58865     2024      12          263605       26360501         CT    47    F
# 58866     2024      12          263615       26361501         CT    60    F
# 58867     2024      12          263615       26361502         CO    36    M
#
#            GrupoEtareo TipoContrato nombreplan CodMatriz ValorPrima  \
# 0      e. 19 - 44 Años   Convenio_1    Clase_J      1782     98.449
# 1      g. 50 - 54 Años   Convenio_1    Clase_J      1782     98.449
# 2      e. 19 - 44 Años   Convenio_1    Clase_J      1782     98.449
# 3      i. 60 - 64 Años   Convenio_1    Clase_J      1782    106.191
# 4      h. 55 - 59 Años   Convenio_1    Clase_J     16767     50.010
# ...                ...          ...        ...       ...        ...
# 58863  g. 50 - 54 Años   Convenio_2    Clase_G      #N/D    131.725
# 58864  h. 55 - 59 Años   Convenio_2    Clase_B      #N/D    130.485
# 58865  f. 45 - 49 Años   Convenio_3    Clase_E         0     41.708
# 58866  i. 60 - 64 Años   Convenio_2    Clase_B      #N/D    139.433
# 58867  e. 19 - 44 Años   Convenio_2    Clase_B      #N/D     62.978
#
#        VrIngConDtoPtoPago Tipo     ciudad  VrIngSinDtoPtoPago
# 0                   93393  Mes      NEIVA               94507
# 1                   93393  Mes      NEIVA               94507
# 2                   93393  Mes      NEIVA               94507
# 3                  100737  Mes      NEIVA              101938
# 4                   50010  Mes      NEIVA               50010
# ...                   ...  ...        ...                 ...
# 58863              131725  Mes   GUAVIARE              131725
# 58864              130485  Mes  CARTAGENA              130485
# 58865               41708  Mes      NEIVA               41708
# 58866              139433  Mes      NEIVA              139433
# 58867               62978  Mes      NEIVA               62978
#
# [3585944 rows x 16 columns]

# %%
Ing_Total['CarnetUsuario'].isna().sum()
# Out:
# np.int64(0)

# %%
Ing_Total['Parentesco'] = Ing_Total['Parentesco'].str.strip()
Ing_Total['Sexo'] = Ing_Total['Sexo'].str.strip()
Ing_Total['TipoContrato'] = Ing_Total['TipoContrato'].str.strip()
Ing_Total['nombreplan'] = Ing_Total['nombreplan'].str.strip()
Ing_Total['Tipo'] = Ing_Total['Tipo'].str.strip()
Ing_Total['ciudad'] = Ing_Total['ciudad'].str.strip()

# %%
Ing_Total['GrupoEtareo'] = Ing_Total['GrupoEtareo'].astype(str).str.replace('  ', ' ')

# %%
Ing_Total['GrupoEtareo'] = (Ing_Total['GrupoEtareo']
                        .str.replace('Á','A')
                        .str.replace('É','E')
                        .str.replace('Í','I')
                        .str.replace('Ó','O')
                        .str.replace('Ú','U')
                        .str.replace('Ñ','N')
                        .str.replace('á','a')
                        .str.replace('é','e')
                        .str.replace('í','i')
                        .str.replace('ó','o')
                        .str.replace('ú','u')
                        .str.replace('ñ','n'))

# %%
Ing_Total['Parentesco'] = Ing_Total['Parentesco'].fillna('0')
Ing_Total['CarnetUsuario'] = Ing_Total['CarnetUsuario'].fillna(98989898)
Ing_Total['Edad'] = Ing_Total['Edad'].fillna(9999)
Ing_Total['Sexo'] = Ing_Total['Sexo'].fillna('0')
Ing_Total['TipoContrato'] = Ing_Total['TipoContrato'].fillna('N')
Ing_Total['nombreplan'] = Ing_Total['nombreplan'].fillna('0')
Ing_Total['CodMatriz'] = Ing_Total['CodMatriz'].fillna(9999)
Ing_Total['Tipo'] = Ing_Total['Tipo'].fillna('0')
Ing_Total['ciudad'] = Ing_Total['ciudad'].fillna('0')

# %%
Ing_Total[Ing_Total['CarnetUsuario'] == 98989898]
# Out:
# Empty DataFrame
# Columns: [AnioIng, MesIng, numerocontrato, CarnetUsuario, Parentesco, Edad, Sexo, GrupoEtareo, TipoContrato, nombreplan, CodMatriz, ValorPrima, VrIngConDtoPtoPago, Tipo, ciudad, VrIngSinDtoPtoPago]
# Index: []

# %%
Ing_Total['CarnetUsuario'] = Ing_Total['CarnetUsuario'].astype(str)
Ing_Total['CarnetUsuario'] = Ing_Total.apply(lambda x:x['CarnetUsuario'].replace('*', ''), axis = 1)

# %%
Ing_Total['Fecha'] = pd.to_datetime(Ing_Total['AnioIng'].astype(str) + '/' + Ing_Total['MesIng'].astype(str).str.zfill(2), format="%Y/%m")

# %%
Ing_Total_1 = Ing_Total[['Fecha', 'AnioIng', 'MesIng', 'ciudad', 'nombreplan', 'numerocontrato', 'TipoContrato', 'CodMatriz', 'CarnetUsuario', 'Edad', 'Sexo', 'GrupoEtareo', 'ValorPrima', 'VrIngConDtoPtoPago']]
Ing_Total_1
# Out:
#            Fecha  AnioIng  MesIng     ciudad nombreplan  numerocontrato  \
# 0     2021-01-01     2021       1      NEIVA    Clase_J          205505
# 1     2021-01-01     2021       1      NEIVA    Clase_J          205505
# 2     2021-01-01     2021       1      NEIVA    Clase_J          205505
# 3     2021-01-01     2021       1      NEIVA    Clase_J          205505
# 4     2021-01-01     2021       1      NEIVA    Clase_J          218120
# ...          ...      ...     ...        ...        ...             ...
# 58863 2024-12-01     2024      12   GUAVIARE    Clase_G          263540
# 58864 2024-12-01     2024      12  CARTAGENA    Clase_B          263595
# 58865 2024-12-01     2024      12      NEIVA    Clase_E          263605
# 58866 2024-12-01     2024      12      NEIVA    Clase_B          263615
# 58867 2024-12-01     2024      12      NEIVA    Clase_B          263615
#
#       TipoContrato CodMatriz CarnetUsuario  Edad Sexo      GrupoEtareo  \
# 0       Convenio_1      1782      20550502    25    M  e. 19 - 44 Anos
# 1       Convenio_1      1782      20550505    51    F  g. 50 - 54 Anos
# 2       Convenio_1      1782      20550506    20    F  e. 19 - 44 Anos
# 3       Convenio_1      1782      20550507    64    F  i. 60 - 64 Anos
# 4       Convenio_1     16767      21812003    58    M  h. 55 - 59 Anos
# ...            ...       ...           ...   ...  ...              ...
# 58863   Convenio_2      #N/D      26354001    50    M  g. 50 - 54 Anos
# 58864   Convenio_2      #N/D      26359501    57    F  h. 55 - 59 Anos
# 58865   Convenio_3         0      26360501    47    F  f. 45 - 49 Anos
# 58866   Convenio_2      #N/D      26361501    60    F  i. 60 - 64 Anos
# 58867   Convenio_2      #N/D      26361502    36    M  e. 19 - 44 Anos
#
#       ValorPrima  VrIngConDtoPtoPago
# 0         98.449               93393
# 1         98.449               93393
# 2         98.449               93393
# 3        106.191              100737
# 4         50.010               50010
# ...          ...                 ...
# 58863    131.725              131725
# 58864    130.485              130485
# 58865     41.708               41708
# 58866    139.433              139433
# 58867     62.978               62978
#
# [3585944 rows x 14 columns]

# %%
Ing_Total_1.to_csv('/content/drive/MyDrive/Usuarios/Resultados/Ingreso_Total.txt', sep=';', encoding='utf-8-sig', index=False)

# %%
Ing_Comp = Ing_Total_1[
    ((Ing_Total_1['AnioIng'] == AnioIng_Actual) & (Ing_Total_1['MesIng'] == MesIng_Actual)) |
    ((Ing_Total_1['AnioIng'] == AnioIng_Anterior) & (Ing_Total_1['MesIng'] == MesIng_Anterior))]

Ing_Comp
# Out:
#            Fecha  AnioIng  MesIng     ciudad nombreplan  numerocontrato  \
# 65599 2023-12-01     2023      12      NEIVA    Clase_J          255610
# 65600 2023-12-01     2023      12      NEIVA    Clase_J          255610
# 65601 2023-12-01     2023      12      NEIVA    Clase_J          255610
# 65602 2023-12-01     2023      12      NEIVA    Clase_E          212695
# 65603 2023-12-01     2023      12      NEIVA    Clase_E          212695
# ...          ...      ...     ...        ...        ...             ...
# 58863 2024-12-01     2024      12   GUAVIARE    Clase_G          263540
# 58864 2024-12-01     2024      12  CARTAGENA    Clase_B          263595
# 58865 2024-12-01     2024      12      NEIVA    Clase_E          263605
# 58866 2024-12-01     2024      12      NEIVA    Clase_B          263615
# 58867 2024-12-01     2024      12      NEIVA    Clase_B          263615
#
#       TipoContrato CodMatriz CarnetUsuario  Edad Sexo      GrupoEtareo  \
# 65599   Convenio_2      #N/D      25561003    30    F  e. 19 - 44 Anos
# 65600   Convenio_2      #N/D      25561004    28    M  e. 19 - 44 Anos
# 65601   Convenio_2      #N/D      25561005     9    F   c. 5 - 14 Anos
# 65602   Convenio_3      #N/D      21269501    67    M   j. 65 - 69Anos
# 65603   Convenio_3      #N/D      21269502    69    F   j. 65 - 69Anos
# ...            ...       ...           ...   ...  ...              ...
# 58863   Convenio_2      #N/D      26354001    50    M  g. 50 - 54 Anos
# 58864   Convenio_2      #N/D      26359501    57    F  h. 55 - 59 Anos
# 58865   Convenio_3         0      26360501    47    F  f. 45 - 49 Anos
# 58866   Convenio_2      #N/D      26361501    60    F  i. 60 - 64 Anos
# 58867   Convenio_2      #N/D      26361502    36    M  e. 19 - 44 Anos
#
#       ValorPrima  VrIngConDtoPtoPago
# 65599    143.436              143436
# 65600    143.436              143436
# 65601    119.131              119131
# 65602    239.430              239430
# 65603    239.430              239430
# ...          ...                 ...
# 58863    131.725              131725
# 58864    130.485              130485
# 58865     41.708               41708
# 58866    139.433              139433
# 58867     62.978               62978
#
# [123890 rows x 14 columns]

# %%
Ing_Comp = Ing_Comp.copy()

# %%
carnets_Anterior = set(Ing_Comp.loc[Ing_Comp['AnioIng'] == AnioIng_Anterior, 'CarnetUsuario'])
carnets_Actual = set(Ing_Comp.loc[Ing_Comp['AnioIng'] == AnioIng_Actual, 'CarnetUsuario'])

# %%
Ing_Comp.loc[Ing_Comp['AnioIng'] == AnioIng_Actual, 'carnets_Actual'] = Ing_Comp.loc[Ing_Comp['AnioIng'] == AnioIng_Actual, 'CarnetUsuario'].apply(
    lambda carnet: "ANTIGUO" if carnet in carnets_Anterior else "0")

# %%
Ing_Comp.loc[Ing_Comp['AnioIng'] == AnioIng_Anterior, 'carnets_Anterior'] = Ing_Comp.loc[Ing_Comp['AnioIng'] == AnioIng_Anterior, 'CarnetUsuario'].apply(
    lambda carnet: "ANTIGUO" if carnet in carnets_Actual else "0")

# %%
Ing_Comp['carnets_Actual'] = Ing_Comp['carnets_Actual'].fillna('0').astype(str)
Ing_Comp['carnets_Anterior'] = Ing_Comp['carnets_Anterior'].fillna('0').astype(str)
Ing_Comp
# Out:
#            Fecha  AnioIng  MesIng     ciudad nombreplan  numerocontrato  \
# 65599 2023-12-01     2023      12      NEIVA    Clase_J          255610
# 65600 2023-12-01     2023      12      NEIVA    Clase_J          255610
# 65601 2023-12-01     2023      12      NEIVA    Clase_J          255610
# 65602 2023-12-01     2023      12      NEIVA    Clase_E          212695
# 65603 2023-12-01     2023      12      NEIVA    Clase_E          212695
# ...          ...      ...     ...        ...        ...             ...
# 58863 2024-12-01     2024      12   GUAVIARE    Clase_G          263540
# 58864 2024-12-01     2024      12  CARTAGENA    Clase_B          263595
# 58865 2024-12-01     2024      12      NEIVA    Clase_E          263605
# 58866 2024-12-01     2024      12      NEIVA    Clase_B          263615
# 58867 2024-12-01     2024      12      NEIVA    Clase_B          263615
#
#       TipoContrato CodMatriz CarnetUsuario  Edad Sexo      GrupoEtareo  \
# 65599   Convenio_2      #N/D      25561003    30    F  e. 19 - 44 Anos
# 65600   Convenio_2      #N/D      25561004    28    M  e. 19 - 44 Anos
# 65601   Convenio_2      #N/D      25561005     9    F   c. 5 - 14 Anos
# 65602   Convenio_3      #N/D      21269501    67    M   j. 65 - 69Anos
# 65603   Convenio_3      #N/D      21269502    69    F   j. 65 - 69Anos
# ...            ...       ...           ...   ...  ...              ...
# 58863   Convenio_2      #N/D      26354001    50    M  g. 50 - 54 Anos
# 58864   Convenio_2      #N/D      26359501    57    F  h. 55 - 59 Anos
# 58865   Convenio_3         0      26360501    47    F  f. 45 - 49 Anos
# 58866   Convenio_2      #N/D      26361501    60    F  i. 60 - 64 Anos
# 58867   Convenio_2      #N/D      26361502    36    M  e. 19 - 44 Anos
#
#       ValorPrima  VrIngConDtoPtoPago carnets_Actual carnets_Anterior
# 65599    143.436              143436              0          ANTIGUO
# 65600    143.436              143436              0          ANTIGUO
# 65601    119.131              119131              0          ANTIGUO
# 65602    239.430              239430              0          ANTIGUO
# 65603    239.430              239430              0          ANTIGUO
# ...          ...                 ...            ...              ...
# 58863    131.725              131725        ANTIGUO                0
# 58864    130.485              130485        ANTIGUO                0
# 58865     41.708               41708        ANTIGUO                0
# 58866    139.433              139433        ANTIGUO                0
# 58867     62.978               62978        ANTIGUO                0
#
# [123890 rows x 16 columns]

# %%
Ing_Comp['Estado'] = np.where(
    (Ing_Comp['carnets_Actual'] == "ANTIGUO") | (Ing_Comp['carnets_Anterior'] == "ANTIGUO"),
    "ANTIGUO",
    "NUEVO"
)

Ing_Comp
# Out:
#            Fecha  AnioIng  MesIng     ciudad nombreplan  numerocontrato  \
# 65599 2023-12-01     2023      12      NEIVA    Clase_J          255610
# 65600 2023-12-01     2023      12      NEIVA    Clase_J          255610
# 65601 2023-12-01     2023      12      NEIVA    Clase_J          255610
# 65602 2023-12-01     2023      12      NEIVA    Clase_E          212695
# 65603 2023-12-01     2023      12      NEIVA    Clase_E          212695
# ...          ...      ...     ...        ...        ...             ...
# 58863 2024-12-01     2024      12   GUAVIARE    Clase_G          263540
# 58864 2024-12-01     2024      12  CARTAGENA    Clase_B          263595
# 58865 2024-12-01     2024      12      NEIVA    Clase_E          263605
# 58866 2024-12-01     2024      12      NEIVA    Clase_B          263615
# 58867 2024-12-01     2024      12      NEIVA    Clase_B          263615
#
#       TipoContrato CodMatriz CarnetUsuario  Edad Sexo      GrupoEtareo  \
# 65599   Convenio_2      #N/D      25561003    30    F  e. 19 - 44 Anos
# 65600   Convenio_2      #N/D      25561004    28    M  e. 19 - 44 Anos
# 65601   Convenio_2      #N/D      25561005     9    F   c. 5 - 14 Anos
# 65602   Convenio_3      #N/D      21269501    67    M   j. 65 - 69Anos
# 65603   Convenio_3      #N/D      21269502    69    F   j. 65 - 69Anos
# ...            ...       ...           ...   ...  ...              ...
# 58863   Convenio_2      #N/D      26354001    50    M  g. 50 - 54 Anos
# 58864   Convenio_2      #N/D      26359501    57    F  h. 55 - 59 Anos
# 58865   Convenio_3         0      26360501    47    F  f. 45 - 49 Anos
# 58866   Convenio_2      #N/D      26361501    60    F  i. 60 - 64 Anos
# 58867   Convenio_2      #N/D      26361502    36    M  e. 19 - 44 Anos
#
#       ValorPrima  VrIngConDtoPtoPago carnets_Actual carnets_Anterior   Estado
# 65599    143.436              143436              0          ANTIGUO  ANTIGUO
# 65600    143.436              143436              0          ANTIGUO  ANTIGUO
# 65601    119.131              119131              0          ANTIGUO  ANTIGUO
# 65602    239.430              239430              0          ANTIGUO  ANTIGUO
# 65603    239.430              239430              0          ANTIGUO  ANTIGUO
# ...          ...                 ...            ...              ...      ...
# 58863    131.725              131725        ANTIGUO                0  ANTIGUO
# 58864    130.485              130485        ANTIGUO                0  ANTIGUO
# 58865     41.708               41708        ANTIGUO                0  ANTIGUO
# 58866    139.433              139433        ANTIGUO                0  ANTIGUO
# 58867     62.978               62978        ANTIGUO                0  ANTIGUO
#
# [123890 rows x 17 columns]

# %%
Ing_Comp.to_csv('/content/drive/MyDrive/Usuarios/Resultados/Comparativo_Ingresos.txt', sep=';', encoding='utf-8-sig', index=False)
